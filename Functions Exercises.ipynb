# %%
# Write a python program to display the fibonacci sequence up to n-th term using recursive function.

n = 10
# Out:
# 0
# 1
# 3
# 5
# 7
# 9
# 11
# 13
# 15
# 17

# %%
'''
Write a python program that prints the numbers form a user-defined start to end range with the following rules:
# For multiples of 3, print "Fizz" instead of the number.
# For multiples of 5, print "Buzz" instead of the number.
# For multiples of both 3 and 5, print "FizzBuzz" instead of the number.
'''
