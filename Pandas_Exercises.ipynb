# %%
import pandas as pd
data = {'Test':[1,2,3],'Test1':[4,5,6],'Test2':[7,8,9]}
df = pd.DataFrame(data, index=[20,22,23])
print(df)
# Out:
#     Test  Test1  Test2
# 20     1      4      7
# 22     2      5      8
# 23     3      6      9
