# %%
import numpy as np
arr = np.array([1,184467440737095516151844674407370955161518446744073709184467440737095516151844674407370955161518446744073709])
arr2 = np.array([1,2,3])
#todo ask doubt about this sizing
print(arr.nbytes)
print(arr2.nbytes)
# Out:
# 16
# 24
