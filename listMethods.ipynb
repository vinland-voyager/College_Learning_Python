# %%
lstex = [1,2,3,4,5,'aa','bb','cc','dd']
lst2 = [9999,10000]

# %%
lstex.insert(1,'HAHAHA')
print(lstex)
# Out:
# [1, 'HAHAHA', 2, 3, 4, 5, 'aa', 'bb', 'cc', 'dd']

# %%
lstex.append('AAA')
print(lstex)
# Out:
# [1, 'HAHAHA', 2, 3, 4, 5, 'aa', 'bb', 'cc', 'dd', 'AAA']

# %%
lstex.extend(lst2)
print(lstex)
# Out:
# [1, 'HAHAHA', 2, 3, 4, 5, 'aa', 'bb', 'cc', 'dd', 'AAA', 9999, 10000]

# %%
lstex.append(lst2)
print(lstex)
# Out:
# [1, 'HAHAHA', 2, 3, 4, 5, 'aa', 'bb', 'cc', 'dd', 'AAA', 9999, 10000, [9999, 10000]]

# %%
lstex.append(1)
lstex.append([1,2])
lstex.append([1,2])
print(lstex)
# Out:
# [1, 'HAHAHA', 2, 3, 4, 5, 'aa', 'bb', 'cc', 'dd', 'AAA', 9999, 10000, [9999, 10000], 1, [1, 2], [1, 2]]

# %%
print(lstex)
lstex.remove(3)
print(lstex)
# Out:
# ['HAHAHA', 2, 4, 'aa', 'bb', 'cc', 'dd', 'AAA', 9999, 10000, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# ['HAHAHA', 2, 4, 'aa', 'bb', 'cc', 'dd', 'AAA', 9999, 10000, 3, 3, 3, 3, 3, 3, 3, 3]

# %%
print(lstex)
print(lstex.pop())
print(lstex)
lstex.pop(3) #deletes the 4th element in list (index: 3)
print(lstex)
# Out:
# ['HAHAHA', 2, 4, 5, 'aa', 'bb', 'cc', 'dd', 'AAA', 9999, 10000, 3, 3, 3, 3, 3]
# 3
# ['HAHAHA', 2, 4, 5, 'aa', 'bb', 'cc', 'dd', 'AAA', 9999, 10000, 3, 3, 3, 3]
# ['HAHAHA', 2, 4, 'aa', 'bb', 'cc', 'dd', 'AAA', 9999, 10000, 3, 3, 3, 3]

# %%
# lstex.clear() # clears the list

del lstex[0] # removes the element at index given
print(lstex)
# del lstex # will delete the list from memory
# Out:
# [2, 3, 4, 5, 'aa', 'bb', 'cc', 'dd']

# %%
lstex.reverse()
print(lstex)
# Out:
# [2, 3, 4, 5, 'aa', 'bb', 'cc', 'dd']

# %%
print(lstex.count(2000))
# Out:
# 0
