# %%
strex = "Aa"
print(strex)
# Out:
# Aa

# %%
print(strex.upper())
# Out:
# AA

# %%
print(strex.lower())
# Out:
# aa

# %%
print(strex.split())
# Out:
# ['Aa']

# %%
print(strex.join(['This', 'will', 'split', 'all', 'words', 'in', 'a', 'list']))
# Join adds each word with the original string
# It does not add space
# Out:
# ThisAawillAasplitAaallAawordsAainAaaAalist

# %%
print(strex.find('a'))
# Out:
# 1

# %%
print(strex.replace('a','b'))
# Out:
# Ab

# %%
print(strex)
# Out:
# Aa
